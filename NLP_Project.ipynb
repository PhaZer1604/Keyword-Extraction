# %% [markdown]
# <a href="https://colab.research.google.com/github/PhaZer1604/Keyword-Extraction/blob/main/NLP_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import spacy
from spacy.displacy.render import EntityRenderer
from IPython.core.display import display, HTML

# %%
# overload the spacy builtin rendering to allow custom POS tags
def custom_render(doc, df, column, options={}, page=False, minify=False, idx=0):
    renderer, converter = EntityRenderer, parse_custom_ents
    renderer = renderer(options=options)
    parsed = [converter(doc, df=df, idx=idx, column=column)]
    html = renderer.render(parsed, page=page, minify=minify).strip()  
    return display(HTML(html))

# parse custom entity types that are not in the original spacy module
def parse_custom_ents(doc, df, idx, column):
    if column in df.columns:
        entities = df[column][idx]
        ents = [{'start': ent[1], 'end': ent[2], 'label': ent[3]} 
                for ent in entities]
    else:
        ents = [{'start': ent.start_char, 'end': ent.end_char, 'label': ent.label_}
            for ent in doc.ents]
    return {'text': doc.text, 'ents': ents, 'title': None}


def render_entities(idx, df, options={}, column='named_ents'):
    text = df['text'][idx]
    custom_render(nlp(text), df=df, column=column, options=options, idx=idx)

# %%
options = {'colors': {'COMPOUND': '#FE6BFE', 'PROPN': '#18CFE6', 'NOUN': '#18CFE6', 'NP': '#1EECA6', 'ENTITY': '#FF8800'}}

pd.set_option('display.max_rows', 10) # edit how jupyter will render our pandas dataframes
pd.options.mode.chained_assignment = None # prevent warning about working on a copy of a dataframe

# %%
nlp = spacy.load('en_core_web_sm')

# %%
df = pd.read_csv('/content/drive/MyDrive/Papers.csv')
df.head()
# Out:
#      Id                                              Title  EventType  \
# 0  5677  Double or Nothing: Multiplicative Incentive Me...     Poster
# 1  5941  Learning with Symmetric Label Noise: The Impor...  Spotlight
# 2  6019   Algorithmic Stability and Uniform Generalization     Poster
# 3  6035  Adaptive Low-Complexity Sequential Inference f...     Poster
# 4  5978  Covariance-Controlled Adaptive Langevin Thermo...     Poster
#
#                                              PdfName  \
# 0  5677-double-or-nothing-multiplicative-incentiv...
# 1  5941-learning-with-symmetric-label-noise-the-i...
# 2  6019-algorithmic-stability-and-uniform-general...
# 3  6035-adaptive-low-complexity-sequential-infere...
# 4  5978-covariance-controlled-adaptive-langevin-t...
#
#                                             Abstract  \
# 0  Crowdsourcing has gained immense popularity in...
# 1  Convex potential minimisation is the de facto ...
# 2  One of the central questions in statistical le...
# 3  We develop a sequential low-complexity inferen...
# 4  Monte Carlo sampling for Bayesian posterior in...
#
#                                            PaperText
# 0  Double or Nothing: Multiplicative\nIncentive M...
# 1  Learning with Symmetric Label Noise: The\nImpo...
# 2  Algorithmic Stability and Uniform Generalizati...
# 3  Adaptive Low-Complexity Sequential Inference f...
# 4  Covariance-Controlled Adaptive Langevin\nTherm...

# %%
lower = lambda x: x.lower() # make lowercase

df = pd.DataFrame(df['Abstract'].apply(lower))
df.columns = ['text']
display(df)
# Out:
#                                                   text
# 0    crowdsourcing has gained immense popularity in...
# 1    convex potential minimisation is the de facto ...
# 2    one of the central questions in statistical le...
# 3    we develop a sequential low-complexity inferen...
# 4    monte carlo sampling for bayesian posterior in...
# ..                                                 ...
# 398  the continuous-time hidden markov model (ct-hm...
# 399  we propose an original particle-based implemen...
# 400  in many statistical problems, a more coarse-gr...
# 401  this paper proposes a distributionally robust ...
# 402  we explore an as yet unexploited opportunity f...
#
# [403 rows x 1 columns]

# %%
# extract a few nouns and beginning, middle and end index using spacy POS tagger
def extract_nouns(text):
    keep_pos = ['PROPN', 'NOUN']
    return [(tok.text, tok.idx, tok.idx+len(tok.text), tok.pos_) for tok in nlp(text) if tok.pos_ in keep_pos]

# create new column in df with extracted nouns
def add_nouns(df):
    df['nouns'] = df['text'].apply(extract_nouns)

# %%
add_nouns(df)
display(df)
# Out:
#                                                   text  \
# 0    crowdsourcing has gained immense popularity in...
# 1    convex potential minimisation is the de facto ...
# 2    one of the central questions in statistical le...
# 3    we develop a sequential low-complexity inferen...
# 4    monte carlo sampling for bayesian posterior in...
# ..                                                 ...
# 398  the continuous-time hidden markov model (ct-hm...
# 399  we propose an original particle-based implemen...
# 400  in many statistical problems, a more coarse-gr...
# 401  this paper proposes a distributionally robust ...
# 402  we explore an as yet unexploited opportunity f...
#
#                                                  nouns
# 0    [(crowdsourcing, 0, 13, NOUN), (popularity, 33...
# 1    [(minimisation, 17, 29, NOUN), (approach, 46, ...
# 2    [(questions, 19, 28, NOUN), (learning, 44, 52,...
# 3    [(complexity, 28, 38, NOUN), (inference, 39, 4...
# 4    [(monte, 0, 5, PROPN), (carlo, 6, 11, PROPN), ...
# ..                                                 ...
# 398  [(time, 15, 19, NOUN), (markov, 27, 33, NOUN),...
# 399  [(particle, 23, 31, NOUN), (implementation, 38...
# 400  [(problems, 20, 28, NOUN), (model, 52, 57, NOU...
# 401  [(paper, 5, 10, NOUN), (approach, 46, 54, NOUN...
# 402  [(opportunity, 33, 44, NOUN), (efficiency, 75,...
#
# [403 rows x 2 columns]

# %%
column = 'nouns'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  has gained immense
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     popularity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     applications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  for obtaining large
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amounts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  of labeled
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# .
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is cheap and fast, but suffers from the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     problem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  of low-
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . to address this fundamental
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     challenge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , we propose a simple
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  to incentivize
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     workers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  to answer only the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     questions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  that they are sure of and skip the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . we show that surprisingly, under a mild and natural no-free-
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lunch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     requirement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , this
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is the one and only
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     incentive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# -compatible
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  possible. we also show that among all possible
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     incentive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; ma

# %%
def extract_noun_phrases(text):
    return [(chunk.text, chunk.start_char, chunk.end_char, chunk.label_) for chunk in nlp(text).noun_chunks]

# create new column in data frame with noun phrase
def add_noun_phrases(df):
    df['noun_phrases'] = df['text'].apply(extract_noun_phrases)

# %%
def visualize_noun_phrases(text):
    df = pd.DataFrame([text]) 
    df.columns = ['text']
    add_noun_phrases(df)
    column = 'noun_phrases'
    render_entities(0, df, options=options, column=column)

# %%
add_noun_phrases(df)
display(df)
# Out:
#                                                   text  \
# 0    crowdsourcing has gained immense popularity in...
# 1    convex potential minimisation is the de facto ...
# 2    one of the central questions in statistical le...
# 3    we develop a sequential low-complexity inferen...
# 4    monte carlo sampling for bayesian posterior in...
# ..                                                 ...
# 398  the continuous-time hidden markov model (ct-hm...
# 399  we propose an original particle-based implemen...
# 400  in many statistical problems, a more coarse-gr...
# 401  this paper proposes a distributionally robust ...
# 402  we explore an as yet unexploited opportunity f...
#
#                                                  nouns  \
# 0    [(crowdsourcing, 0, 13, NOUN), (popularity, 33...
# 1    [(minimisation, 17, 29, NOUN), (approach, 46, ...
# 2    [(questions, 19, 28, NOUN), (learning, 44, 52,...
# 3    [(complexity, 28, 38, NOUN), (inference, 39, 4...
# 4    [(monte, 0, 5, PROPN), (carlo, 6, 11, PROPN), ...
# ..                                                 ...
# 398  [(time, 15, 19, NOUN), (markov, 27, 33, NOUN),...
# 399  [(particle, 23, 31, NOUN), (implementation, 38...
# 400  [(problems, 20, 28, NOUN), (model, 52, 57, NOU...
# 401  [(paper, 5, 10, NOUN), (approach, 46, 54, NOUN...
# 402  [(opportunity, 33, 44, NOUN), (efficiency, 75,...
#
#                                           noun_phrases
# 0    [(crowdsourcing, 0, 13, NP), (immense populari...
# 1    [(convex potential minimisation, 0, 29, NP), (...
# 2    [(the central questions, 7, 28, NP), (statisti...
# 3    [(we, 0, 2, NP), (a sequential low-complexity ...
# 4    [(bayesian posterior inference, 25, 53, NP), (...
# ..                                                 ...
# 398  [(the continuous-time hidden markov model, 0, ...
# 399  [(we, 0, 2, NP), (an original particle-based i...
# 400  [(many statistical problems, 3, 28, NP), (a mo...
# 401  [(this paper, 0, 10, NP), (a distributionally ...
# 402  [(we, 0, 2, NP), (unexploited opportunity, 21,...
#
# [403 rows x 3 columns]

# %%
column = 'noun_phrases'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  has gained
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     immense popularity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  in
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning applications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  for obtaining
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     large amounts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  of
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     labeled data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is cheap and fast, but suffers from
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the problem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  of
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     low-quality data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# . to address
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this fundamental challenge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  in
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# ,
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     we
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  propose
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a simple payment mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  to incentivize
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     workers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  to answer
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only the questions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     that
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     they
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  are sure of and skip
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the rest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     we
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  show that surprisingly, under
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a mild and natural no-free-lunch requirement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# ,
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the one and only incentive-compatible payment mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  possible.
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     we
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  also show that among
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     all possible incentive-compatible  mechanisms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  (
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     that
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  may or may not satisfy
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     no-free-lunch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical

# %%
# Extract compound noun phrases with beginning and end idx
def extract_compounds(text):
    comp_idx = 0
    compound = []
    compound_nps = []
    tok_idx = 0
    for idx, tok in enumerate(nlp(text)):
        if tok.dep_ == 'compound':       # .dep_ is used to get the type of syntactic relation

            # capture if any hyphenated compounds are there
            children = ''.join([c.text for c in tok.children])
            if '-' in children:
                compound.append(''.join([children, tok.text]))
            else:
                compound.append(tok.text)

            # store starting index of compound phrase
            try:
                tok_idx = [c for c in tok.children][0].idx
            except IndexError:
                if len(compound) == 1:
                    tok_idx = tok.idx
            comp_idx = tok.i

        # append the last word in a compound phrase
        if tok.i - comp_idx == 1:
            compound.append(tok.text)
            if len(compound) > 1: 
                compound = ' '.join(compound)
                compound_nps.append((compound, tok_idx, tok_idx+len(compound), 'COMPOUND'))

            # reset parameters
            tok_idx = 0 
            compound = []

    return compound_nps


def add_compounds(df):
    df['compounds'] = df['text'].apply(extract_compounds)

# %%
add_compounds(df)
display(df)
# Out:
#                                                   text  \
# 0    crowdsourcing has gained immense popularity in...
# 1    convex potential minimisation is the de facto ...
# 2    one of the central questions in statistical le...
# 3    we develop a sequential low-complexity inferen...
# 4    monte carlo sampling for bayesian posterior in...
# ..                                                 ...
# 398  the continuous-time hidden markov model (ct-hm...
# 399  we propose an original particle-based implemen...
# 400  in many statistical problems, a more coarse-gr...
# 401  this paper proposes a distributionally robust ...
# 402  we explore an as yet unexploited opportunity f...
#
#                                                  nouns  \
# 0    [(crowdsourcing, 0, 13, NOUN), (popularity, 33...
# 1    [(minimisation, 17, 29, NOUN), (approach, 46, ...
# 2    [(questions, 19, 28, NOUN), (learning, 44, 52,...
# 3    [(complexity, 28, 38, NOUN), (inference, 39, 4...
# 4    [(monte, 0, 5, PROPN), (carlo, 6, 11, PROPN), ...
# ..                                                 ...
# 398  [(time, 15, 19, NOUN), (markov, 27, 33, NOUN),...
# 399  [(particle, 23, 31, NOUN), (implementation, 38...
# 400  [(problems, 20, 28, NOUN), (model, 52, 57, NOU...
# 401  [(paper, 5, 10, NOUN), (approach, 46, 54, NOUN...
# 402  [(opportunity, 33, 44, NOUN), (efficiency, 75,...
#
#                                           noun_phrases  \
# 0    [(crowdsourcing, 0, 13, NP), (immense populari...
# 1    [(convex potential minimisation, 0, 29, NP), (...
# 2    [(the central questions, 7, 28, NP), (statisti...
# 3    [(we, 0, 2, NP), (a sequential low-complexity ...
# 4    [(bayesian posterior inference, 25, 53, NP), (...
# ..                                                 ...
# 398  [(the continuous-time hidden markov model, 0, ...
# 399  [(we, 0, 2, NP), (an original particle-based i...
# 400  [(many statistical problems, 3, 28, NP), (a mo...
# 401  [(this paper, 0, 10, NP), (a distributionally ...
# 402  [(we, 0, 2, NP), (unexploited opportunity, 21,...
#
#                                              compounds
# 0    [(machine learning applications, 47, 76, COMPO...
# 1    [(label noise, 143, 154, COMPOUND), (linear fu...
# 2    [(learning theory, 32, 47, COMPOUND), (inferen...
# 3    [(low-complexity inference procedure, 24, 58, ...
# 4    [(monte carlo sampling, 0, 20, COMPOUND), (mac...
# ..                                                 ...
# 398  [(markov model, 27, 39, COMPOUND), (ct -, 41, ...
# 399  [(belief propagation, 60, 78, COMPOUND), (pair...
# 400  [(population -, 78, 90, COMPOUND), (population...
# 401  [(wasserstein distance, 90, 110, COMPOUND), (p...
# 402  [(stochastic gradient, 89, 108, COMPOUND), (mo...
#
# [403 rows x 4 columns]

# %%
column = 'compounds'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">crowdsourcing has gained immense popularity in
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning applications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  for obtaining large amounts of labeled data. crowdsourcing is cheap and fast, but suffers from the problem of
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     low-quality data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# . to address this fundamental challenge in crowdsourcing, we propose a simple
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  to incentivize workers to answer only the questions that they are sure of and skip the rest. we show that surprisingly, under a mild and natural
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     no-free-lunch requirement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# , this mechanism is the one and only incentive-compatible
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  possible. we also show that among all possible incentive-compatible  mechanisms (that may or may not satisfy no-free-lunch), our mechanism makes the smallest possible payment to spammers.  interestingly, this unique mechanism takes a multiplicative form. the simplicity of the mechanism is an added benefit.  in preliminary experiments involving over several hundred workers, we observe a significant reduction in the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     error rates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  under our unique mechanism for the same or lower monetary expenditure.</div>

# %%
# combine compound noun phrases and entities
def extract_comp_nouns(row_series, cols=[]):
    return {noun_tuple[0] for col in cols for noun_tuple in row_series[col]}


def add_comp_nouns(df, cols=[]):
    df['comp_nouns'] = df.apply(extract_comp_nouns, axis=1, cols=cols)

# %%
cols = ['nouns', 'compounds']
add_comp_nouns(df, cols=cols)
display(df)
# Out:
#                                                   text  \
# 0    crowdsourcing has gained immense popularity in...
# 1    convex potential minimisation is the de facto ...
# 2    one of the central questions in statistical le...
# 3    we develop a sequential low-complexity inferen...
# 4    monte carlo sampling for bayesian posterior in...
# ..                                                 ...
# 398  the continuous-time hidden markov model (ct-hm...
# 399  we propose an original particle-based implemen...
# 400  in many statistical problems, a more coarse-gr...
# 401  this paper proposes a distributionally robust ...
# 402  we explore an as yet unexploited opportunity f...
#
#                                                  nouns  \
# 0    [(crowdsourcing, 0, 13, NOUN), (popularity, 33...
# 1    [(minimisation, 17, 29, NOUN), (approach, 46, ...
# 2    [(questions, 19, 28, NOUN), (learning, 44, 52,...
# 3    [(complexity, 28, 38, NOUN), (inference, 39, 4...
# 4    [(monte, 0, 5, PROPN), (carlo, 6, 11, PROPN), ...
# ..                                                 ...
# 398  [(time, 15, 19, NOUN), (markov, 27, 33, NOUN),...
# 399  [(particle, 23, 31, NOUN), (implementation, 38...
# 400  [(problems, 20, 28, NOUN), (model, 52, 57, NOU...
# 401  [(paper, 5, 10, NOUN), (approach, 46, 54, NOUN...
# 402  [(opportunity, 33, 44, NOUN), (efficiency, 75,...
#
#                                           noun_phrases  \
# 0    [(crowdsourcing, 0, 13, NP), (immense populari...
# 1    [(convex potential minimisation, 0, 29, NP), (...
# 2    [(the central questions, 7, 28, NP), (statisti...
# 3    [(we, 0, 2, NP), (a sequential low-complexity ...
# 4    [(bayesian posterior inference, 25, 53, NP), (...
# ..                                                 ...
# 398  [(the continuous-time hidden markov model, 0, ...
# 399  [(we, 0, 2, NP), (an original particle-based i...
# 400  [(many statistical problems, 3, 28, NP), (a mo...
# 401  [(this paper, 0, 10, NP), (a distributionally ...
# 402  [(we, 0, 2, NP), (unexploited opportunity, 21,...
#
#                                              compounds  \
# 0    [(machine learning applications, 47, 76, COMPO...
# 1    [(label noise, 143, 154, COMPOUND), (linear fu...
# 2    [(learning theory, 32, 47, COMPOUND), (inferen...
# 3    [(low-complexity inference procedure, 24, 58, ...
# 4    [(monte carlo sampling, 0, 20, COMPOUND), (mac...
# ..                                                 ...
# 398  [(markov model, 27, 39, COMPOUND), (ct -, 41, ...
# 399  [(belief propagation, 60, 78, COMPOUND), (pair...
# 400  [(population -, 78, 90, COMPOUND), (population...
# 401  [(wasserstein distance, 90, 110, COMPOUND), (p...
# 402  [(stochastic gradient, 89, 108, COMPOUND), (mo...
#
#                                             comp_nouns
# 0    {incentive, machine learning applications, mac...
# 1    {potential, label noise, solution, losses, los...
# 2    {experience, relationship, pac, process, dimen...
# 3    {dirichlet process mixtures, parameter, asympt...
# 4    {parameter, langevin, setting, schemes, machin...
# ..                                                 ...
# 398  {parameter, ct-hmm models, ct -, models, disea...
# 399  {expectation, scheme, ep, family, proposal, pr...
# 400  {populations, electricity, bayesian melding, s...
# 401  {misclassification probability, wasserstein di...
# 402  {reparameterizations, convergence.we, connecti...
#
# [403 rows x 5 columns]

# %%
# take a look at combined entities
df['comp_nouns'][0]
# Out:
# {'amounts',
#  'applications',
#  'benefit',
#  'challenge',
#  'crowdsourcing',
#  'data',
#  'error',
#  'error rates',
#  'expenditure',
#  'experiments',
#  'form',
#  'incentive',
#  'learning',
#  'low-quality data',
#  'lunch',
#  'machine',
#  'machine learning applications',
#  'mechanism',
#  'mechanisms',
#  'no-free-lunch requirement',
#  'payment',
#  'payment mechanism',
#  'popularity',
#  'problem',
#  'quality',
#  'questions',
#  'rates',
#  'reduction',
#  'requirement',
#  'rest',
#  'simplicity',
#  'spammers',
#  'workers'}

# %%
df2 = pd.read_csv('/content/drive/MyDrive/freq_words.csv')
df2
# Out:
#         Rank          Word Part of speech   Frequency  Dispersion  Unnamed: 5  \
# 0        NaN           NaN            NaN         NaN         NaN         NaN
# 1        1.0           the              a  22038615.0        0.98         NaN
# 2        2.0            be              v  12545825.0        0.97         NaN
# 3        3.0           and              c  10741073.0        0.99         NaN
# 4        4.0            of              i  10343885.0        0.97         NaN
# ...      ...           ...            ...         ...         ...         ...
# 4996  4996.0     plaintiff              n      5312.0        0.88         NaN
# 4997  4997.0           kid              v      5094.0        0.92         NaN
# 4998  4998.0  middle-class              j      5025.0        0.93         NaN
# 4999  4999.0       apology              n      4972.0        0.94         NaN
# 5000  5000.0          till              i      5079.0        0.92         NaN
#
#       Unnamed: 6
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 4996         NaN
# 4997         NaN
# 4998         NaN
# 4999         NaN
# 5000         NaN
#
# [5001 rows x 7 columns]

# %%
freq_words = df2['Word'].iloc[1:]
display(freq_words)
# Out:
# 1                the
# 2                 be
# 3                and
# 4                 of
# 5                  a
#             ...
# 4996       plaintiff
# 4997             kid
# 4998    middle-class
# 4999         apology
# 5000            till
# Name: Word, Length: 5000, dtype: object

# %%
# drop any entities that are already captured by noun phrases
def drop_duplicate_np_splits(ents):
    drop_ents = set()
    for ent in ents:
        if len(ent.split(' ')) > 1:
            for e in ent.split(' '):
                if e in ents:
                    drop_ents.add(e)
    return ents - drop_ents


# within an entity, drop single characters
def drop_single_char_nps(ents):
    return {' '.join([e for e in ent.split(' ') if not len(e) == 1]) for ent in ents}


# drop any entities that are less than three characters
def drop_double_char(ents):
    drop_ents = {ent for ent in ents if len(ent) < 3}
    return ents - drop_ents


# keep only entities with alphabets, hyphens, and spaces
def keep_alpha(ents):
    keep_char = set('-abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ ')
    drop_ents = {ent for ent in ents if not set(ent).issubset(keep_char)}
    return ents - drop_ents

# %%
# drop any entities in the 5000 most common words in the English langauge
def remove_freq_words(ents):
    freq_words = pd.read_csv('/content/drive/MyDrive/freq_words.csv')['Word'].iloc[1:]
    for word in freq_words:
        try:
            ents.remove(word)
        except KeyError:
            continue
    return ents


def add_clean_ents(df, funcs=[]):
    col = 'clean_ents'
    df[col] = df['comp_nouns']
    for f in funcs:
        df[col] = df[col].apply(f)

# %%
funcs = [drop_duplicate_np_splits, drop_double_char, keep_alpha, drop_single_char_nps, remove_freq_words]
add_clean_ents(df, funcs)
display(df)
# Out:
#                                                   text  \
# 0    crowdsourcing has gained immense popularity in...
# 1    convex potential minimisation is the de facto ...
# 2    one of the central questions in statistical le...
# 3    we develop a sequential low-complexity inferen...
# 4    monte carlo sampling for bayesian posterior in...
# ..                                                 ...
# 398  the continuous-time hidden markov model (ct-hm...
# 399  we propose an original particle-based implemen...
# 400  in many statistical problems, a more coarse-gr...
# 401  this paper proposes a distributionally robust ...
# 402  we explore an as yet unexploited opportunity f...
#
#                                                  nouns  \
# 0    [(crowdsourcing, 0, 13, NOUN), (popularity, 33...
# 1    [(minimisation, 17, 29, NOUN), (approach, 46, ...
# 2    [(questions, 19, 28, NOUN), (learning, 44, 52,...
# 3    [(complexity, 28, 38, NOUN), (inference, 39, 4...
# 4    [(monte, 0, 5, PROPN), (carlo, 6, 11, PROPN), ...
# ..                                                 ...
# 398  [(time, 15, 19, NOUN), (markov, 27, 33, NOUN),...
# 399  [(particle, 23, 31, NOUN), (implementation, 38...
# 400  [(problems, 20, 28, NOUN), (model, 52, 57, NOU...
# 401  [(paper, 5, 10, NOUN), (approach, 46, 54, NOUN...
# 402  [(opportunity, 33, 44, NOUN), (efficiency, 75,...
#
#                                           noun_phrases  \
# 0    [(crowdsourcing, 0, 13, NP), (immense populari...
# 1    [(convex potential minimisation, 0, 29, NP), (...
# 2    [(the central questions, 7, 28, NP), (statisti...
# 3    [(we, 0, 2, NP), (a sequential low-complexity ...
# 4    [(bayesian posterior inference, 25, 53, NP), (...
# ..                                                 ...
# 398  [(the continuous-time hidden markov model, 0, ...
# 399  [(we, 0, 2, NP), (an original particle-based i...
# 400  [(many statistical problems, 3, 28, NP), (a mo...
# 401  [(this paper, 0, 10, NP), (a distributionally ...
# 402  [(we, 0, 2, NP), (unexploited opportunity, 21,...
#
#                                              compounds  \
# 0    [(machine learning applications, 47, 76, COMPO...
# 1    [(label noise, 143, 154, COMPOUND), (linear fu...
# 2    [(learning theory, 32, 47, COMPOUND), (inferen...
# 3    [(low-complexity inference procedure, 24, 58, ...
# 4    [(monte carlo sampling, 0, 20, COMPOUND), (mac...
# ..                                                 ...
# 398  [(markov model, 27, 39, COMPOUND), (ct -, 41, ...
# 399  [(belief propagation, 60, 78, COMPOUND), (pair...
# 400  [(population -, 78, 90, COMPOUND), (population...
# 401  [(wasserstein distance, 90, 110, COMPOUND), (p...
# 402  [(stochastic gradient, 89, 108, COMPOUND), (mo...
#
#                                             comp_nouns  \
# 0    {incentive, machine learning applications, mac...
# 1    {potential, label noise, solution, losses, los...
# 2    {experience, relationship, pac, process, dimen...
# 3    {dirichlet process mixtures, parameter, asympt...
# 4    {parameter, langevin, setting, schemes, machin...
# ..                                                 ...
# 398  {parameter, ct-hmm models, ct -, models, disea...
# 399  {expectation, scheme, ep, family, proposal, pr...
# 400  {populations, electricity, bayesian melding, s...
# 401  {misclassification probability, wasserstein di...
# 402  {reparameterizations, convergence.we, connecti...
#
#                                             clean_ents
# 0    {machine learning applications, questions, pay...
# 1    {label noise, losses, modification, svm, linea...
# 2    {dimensionality reduction methods, questions, ...
# 3    {dirichlet process mixtures, data sets, low-co...
# 4    {parameter, schemes, target distribution, equa...
# ..                                                 ...
# 398  {parameter, ct-hmm models, computation, diseas...
# 399  {beliefs, particle belief propagation, expecta...
# 400  {bayesian melding, source separation problem, ...
# 401  {misclassification probability, wasserstein di...
# 402  {reparameterizations, posteriors, regularizati...
#
# [403 rows x 6 columns]

# %%
def visualize_entities(df, idx=0):
    ents = []
    abstract = df['text'][idx]
    for ent in df['clean_ents'][idx]:
        i = abstract.find(ent) # locate the index of the entity in the abstract
        ents.append((ent, i, i+len(ent), 'ENTITY')) 
    ents.sort(key=lambda tup: tup[1])

    dummy_df = pd.DataFrame([abstract, ents]).T
    dummy_df.columns = ['text', 'clean_ents']
    column = 'clean_ents'
    render_entities(0, dummy_df, options=options, column=column)

# %%
visualize_entities(df, 0)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  has gained immense popularity in
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning applications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  for obtaining large
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amounts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of labeled data. crowdsourcing is cheap and fast, but suffers from the problem of
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     low-quality data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . to address this fundamental challenge in crowdsourcing, we propose a simple
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  to incentivize
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     workers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  to answer only the
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     questions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  that they are sure of and skip the rest. we show that surprisingly, under a mild and natural
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     no-free-lunch requirement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , this mechanism is the one and only incentive-compatible payment mechanism possible. we also show that among all possible incentive-compatible
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mechanisms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  (that may or may not satisfy no-free-lunch), our mechanism makes the smallest possible payment to
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spammers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .  interestingly, this unique mechanism takes a multiplicative form. the
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     simplicity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of the mechanism is an added benefit.  in preliminary
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     experiments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  involving over several hundred workers, we observe a significant reduction in the
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     error rates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  under our unique mechanism for the same or lower monetary
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     expenditure
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</div>

# %%
column = 'nouns'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  has gained immense
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     popularity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     applications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  for obtaining large
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amounts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  of labeled
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# .
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is cheap and fast, but suffers from the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     problem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  of low-
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . to address this fundamental
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     challenge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crowdsourcing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , we propose a simple
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  to incentivize
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     workers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  to answer only the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     questions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  that they are sure of and skip the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . we show that surprisingly, under a mild and natural no-free-
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lunch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     requirement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , this
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is the one and only
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     incentive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# -compatible
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mechanism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  possible. we also show that among all possible
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     incentive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; ma

# %%
# text = df.at[0, 'text']
text = "When designing Natural Language Processing applications that use Machine Learning techniques, feature extraction becomes a significant part of the development effort, whether developing a new application or attempting to reproduce results reported for existing NLP tasks. We present EDISON, a Java library of feature generation functions used in a suite of state-of-the-art NLP tools, based on a set of generic NLP data structures. These feature extractors populate simple data structures encoding the extracted features, which the package can also serialize to an intuitive JSON file format that can be easily mapped to formats used by ML packages. EDISON can also be used programmatically with JVM-based (Java/Scala) NLP software to provide the feature extractor input. The collection of feature extractors is organised hierarchically and a simple search interface is provided. In this paper we include examples that demonstrate the versatility and ease-of-use of the EDISON feature extraction suite to show that this can significantly reduce the time spent by developers on feature extraction design for NLP systems. "
doc = nlp(text)

from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When designing
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Natural Language Processing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  applications that use
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Machine Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  techniques, feature extraction becomes a significant part of the development effort, whether developing a new application or attempting to reproduce results reported for existing
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tasks. We present
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EDISON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  library of feature generation functions used in a suite of state-of-the-art
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tools, based on a set of generic
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  data structures. These feature extractors populate simple data structures encoding the extracted features, which the package can also serialize to an intuitive JSON file format that can be easily mapped to formats used by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ML
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  packages. EDISON can also be used programmatically with JVM-based (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java/Scala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# )
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  software to provide the feature extractor input. The collection of feature extractors is organised hierarchically and a simple search interface is provided. In this paper we include examples that demonstrate the versatility and ease-of-use of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EDISON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  feature extraction suite to show that this can significantly reduce the time spent by developers on feature extraction design for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  systems. </div></span>

# %%
text = "When designing Natural Language Processing applications that use Machine Learning techniques, feature extraction becomes a significant part of the development effort, whether developing a new application or attempting to reproduce results reported for existing NLP tasks. We present EDISON, a Java library of feature generation functions used in a suite of state-of-the-art NLP tools, based on a set of generic NLP data structures. These feature extractors populate simple data structures encoding the extracted features, which the package can also serialize to an intuitive JSON file format that can be easily mapped to formats used by ML packages. EDISON can also be used programmatically with JVM-based (Java/Scala) NLP software to provide the feature extractor input. The collection of feature extractors is organised hierarchically and a simple search interface is provided. In this paper we include examples that demonstrate the versatility and ease-of-use of the EDISON feature extraction suite to show that this can significantly reduce the time spent by developers on feature extraction design for NLP systems. "
text = text.lower()

sample_df = pd.DataFrame({'text': [text]})

add_nouns(sample_df)

add_compounds(sample_df)

cols = ['nouns', 'compounds']
add_comp_nouns(sample_df, cols=cols)

funcs = [drop_duplicate_np_splits, drop_double_char, keep_alpha, drop_single_char_nps, remove_freq_words]
add_clean_ents(sample_df, funcs)

visualize_entities(sample_df, 0)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">when designing natural
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     language processing applications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  that use
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning techniques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ,
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feature extraction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  becomes a significant part of the
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     development effort
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , whether developing a new application or attempting to reproduce
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     results
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  reported for existing
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nlp tasks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . we present
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     edison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , a
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  library of
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feature generation functions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  used in a suite of state-of-the-art nlp
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tools
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , based on a set of generic
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nlp data structures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data structures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . these
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feature extractors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  populate simple data structures encoding the extracted
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     features
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , which the package can also serialize to an intuitive
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     json file format
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  that can be easily mapped to
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     formats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  used by
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ml packages
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . edison can also be used programmatically with
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jvm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# -based (java/
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     scala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# )
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nlp software
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  to provide the
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feature extractor input
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . the collection of feature extractors is organised hierarchically and a simple
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     search interface
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  is provided. in this paper we include
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     examples
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  that demonstrate the
# <mark class="entity" style="background: #FF8800; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     versatility
#     <spa
